# %% [markdown]
# # Scenic+ (GRNs build)
#
# Construcció de xarxes reguladores gèniques amb SCENIC+.
#
# ## Què es fa en aquesta secció
# - Objectiu analític
# - Inputs i formats esperats
# - Passos del pipeline
# - Resultats i criteris de qualitat
